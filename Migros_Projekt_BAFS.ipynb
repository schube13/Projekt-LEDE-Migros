# %%
#From BAFS I can have the monthly Index for Inflation -  migros_montlicher_Einkaufskorb_BAFS
#there are categories like Kaffee (Detailhandel) but also Energy-Prices
#df_4 = pd.read_excel('migros_hauptkategorien_Einkaufskorb_BASF.xsxl')
#df_4
#----> New Notebook!

# %%
import pandas as pd

# %%
df_T = pd.read_excel('Teuerung_23_25.xlsx')
df_T.head()
# Out:
#                Position_D        PosTxt_D  2023-01-01 00:00:00  \
# 0                     NaN             NaN                  NaN
# 1          Nahrungsmittel  Nahrungsmittel             103.8223
# 2                 Energie         Energie             154.1562
#
#    2023-02-01 00:00:00  2023-03-01 00:00:00  2023-04-01 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1             104.9831             105.7529             104.7388
# 2             152.7693             151.8754             149.8897
#
#    2023-05-01 00:00:00  2023-06-01 00:00:00  2023-07-01 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1             106.4792             107.6272             108.1987
# 2             147.2592             147.3710             147.8984
#
#    2023-08-01 00:00:00  ...  2024-08-01 00:00:00  2024-09-01 00:00:00  \
# 0                  NaN  ...                  NaN                  NaN
# ...

# %%
# Swap rows and columns
df_TE = df_T.T.reset_index()

# Display the transposed DataFrame
print(df_TE)
# Out:
#                   index    0                       1                2
# 0            Position_D  NaN          Nahrungsmittel          Energie
# 1              PosTxt_D  NaN          Nahrungsmittel          Energie
# 2   2023-01-01 00:00:00  NaN                103.8223         154.1562
# 3   2023-02-01 00:00:00  NaN                104.9831         152.7693
# 4   2023-03-01 00:00:00  NaN                105.7529         151.8754
# 5   2023-04-01 00:00:00  NaN                104.7388         149.8897
# 6   2023-05-01 00:00:00  NaN                106.4792         147.2592
# 7   2023-06-01 00:00:00  NaN                107.6272          147.371
# 8   2023-07-01 00:00:00  NaN                108.1987         147.8984
# 9   2023-08-01 00:00:00  NaN                108.0516         149.9333
# 10  2023-09-01 00:00:00  NaN                107.5328          151.194
# 11  2023-10-01 00:00:00  NaN                107.3307         151.8005
# ...

# %%
df_TE.describe
# Out:
# <bound method NDFrame.describe of                   index    0                       1                2
# 0            Position_D  NaN          Nahrungsmittel          Energie
# 1              PosTxt_D  NaN          Nahrungsmittel          Energie
# 2   2023-01-01 00:00:00  NaN                103.8223         154.1562
# 3   2023-02-01 00:00:00  NaN                104.9831         152.7693
# 4   2023-03-01 00:00:00  NaN                105.7529         151.8754
# 5   2023-04-01 00:00:00  NaN                104.7388         149.8897
# 6   2023-05-01 00:00:00  NaN                106.4792         147.2592
# 7   2023-06-01 00:00:00  NaN                107.6272          147.371
# 8   2023-07-01 00:00:00  NaN                108.1987         147.8984
# 9   2023-08-01 00:00:00  NaN                108.0516         149.9333
# 10  2023-09-01 00:00:00  NaN                107.5328          151.194
# 11  2023-10-01 00:00:00  NaN                107.3307         151.8005
# ...

# %%
df_TE = df_TE.iloc[2:]

# %%
df_TE.head()
# Out:
#                  index    0         1         2
# 2  2023-01-01 00:00:00  NaN  103.8223  154.1562
# 3  2023-02-01 00:00:00  NaN  104.9831  152.7693
# 4  2023-03-01 00:00:00  NaN  105.7529  151.8754
# 5  2023-04-01 00:00:00  NaN  104.7388  149.8897
# 6  2023-05-01 00:00:00  NaN  106.4792  147.2592

# %%
print(df_TE.columns)
# Out:
# Index(['index', 0, 1, 2], dtype='object')

# %%
column_names = df_TE.columns.tolist()
print(column_names)
# Out:
# ['index', 0, 1, 2]

# %%
df_TE.dropna(axis=1, how="all")
# Out:
#                   index         1         2
# 2   2023-01-01 00:00:00  103.8223  154.1562
# 3   2023-02-01 00:00:00  104.9831  152.7693
# 4   2023-03-01 00:00:00  105.7529  151.8754
# 5   2023-04-01 00:00:00  104.7388  149.8897
# 6   2023-05-01 00:00:00  106.4792  147.2592
# 7   2023-06-01 00:00:00  107.6272   147.371
# 8   2023-07-01 00:00:00  108.1987  147.8984
# 9   2023-08-01 00:00:00  108.0516  149.9333
# 10  2023-09-01 00:00:00  107.5328   151.194
# 11  2023-10-01 00:00:00  107.3307  151.8005
# 12  2023-11-01 00:00:00   106.659  150.2488
# 13  2023-12-01 00:00:00  105.9498   149.036
# 14  2024-01-01 00:00:00  106.1015  161.2011
# 15  2024-02-01 00:00:00  105.7117  162.6236
# 16  2024-03-01 00:00:00  105.1746  161.8581
# 17  2024-04-01 00:00:00  105.6052  161.4541
# 18  2024-05-01 00:00:00  106.7913  159.6954
# 19  2024-06-01 00:00:00    107.25  159.5037
# 20  2024-07-01 00:00:00  108.2627   160.057
# 21  2024-08-01 00:00:00  107.8013  158.2215
# ...

# %%
#df_TE.columns=["Date", "Nahrungsmittel", "Energie"]

# %%
df_TE['index'] = pd.to_datetime(df_TE['index'])
# Out:
# C:\Users\ursul\AppData\Local\Temp\ipykernel_17692\3378167589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TE['index'] = pd.to_datetime(df_TE['index'])

# %%
df_TE
# Out:
#         index    0         1         2
# 2  2023-01-01  NaN  103.8223  154.1562
# 3  2023-02-01  NaN  104.9831  152.7693
# 4  2023-03-01  NaN  105.7529  151.8754
# 5  2023-04-01  NaN  104.7388  149.8897
# 6  2023-05-01  NaN  106.4792  147.2592
# 7  2023-06-01  NaN  107.6272   147.371
# 8  2023-07-01  NaN  108.1987  147.8984
# 9  2023-08-01  NaN  108.0516  149.9333
# 10 2023-09-01  NaN  107.5328   151.194
# 11 2023-10-01  NaN  107.3307  151.8005
# 12 2023-11-01  NaN   106.659  150.2488
# 13 2023-12-01  NaN  105.9498   149.036
# 14 2024-01-01  NaN  106.1015  161.2011
# 15 2024-02-01  NaN  105.7117  162.6236
# 16 2024-03-01  NaN  105.1746  161.8581
# 17 2024-04-01  NaN  105.6052  161.4541
# 18 2024-05-01  NaN  106.7913  159.6954
# 19 2024-06-01  NaN    107.25  159.5037
# 20 2024-07-01  NaN  108.2627   160.057
# 21 2024-08-01  NaN  107.8013  158.2215
# 22 2024-09-01  NaN  107.7157  157.1795
# 23 2024-10-01  NaN  106.8659   156.313
# 24 2024-11-01  NaN  105.7329  156.9732
# ...

# %%
df_clean = df_TE.dropna(axis=1, how="all")
df_clean
# Out:
#         index         1         2
# 2  2023-01-01  103.8223  154.1562
# 3  2023-02-01  104.9831  152.7693
# 4  2023-03-01  105.7529  151.8754
# 5  2023-04-01  104.7388  149.8897
# 6  2023-05-01  106.4792  147.2592
# 7  2023-06-01  107.6272   147.371
# 8  2023-07-01  108.1987  147.8984
# 9  2023-08-01  108.0516  149.9333
# 10 2023-09-01  107.5328   151.194
# 11 2023-10-01  107.3307  151.8005
# 12 2023-11-01   106.659  150.2488
# 13 2023-12-01  105.9498   149.036
# 14 2024-01-01  106.1015  161.2011
# 15 2024-02-01  105.7117  162.6236
# 16 2024-03-01  105.1746  161.8581
# 17 2024-04-01  105.6052  161.4541
# 18 2024-05-01  106.7913  159.6954
# 19 2024-06-01    107.25  159.5037
# 20 2024-07-01  108.2627   160.057
# 21 2024-08-01  107.8013  158.2215
# 22 2024-09-01  107.7157  157.1795
# 23 2024-10-01  106.8659   156.313
# 24 2024-11-01  105.7329  156.9732
# 25 2024-12-01  104.6587  157.1756
# 26 2025-01-01   104.839  149.7685
# 27 2025-02-01  104.7204  149.4796
# ...

# %%
df_clean.columns=["Date", "Nahrungsmittel", "Energie"]
df_clean
# Out:
#          Date Nahrungsmittel   Energie
# 2  2023-01-01       103.8223  154.1562
# 3  2023-02-01       104.9831  152.7693
# 4  2023-03-01       105.7529  151.8754
# 5  2023-04-01       104.7388  149.8897
# 6  2023-05-01       106.4792  147.2592
# 7  2023-06-01       107.6272   147.371
# 8  2023-07-01       108.1987  147.8984
# 9  2023-08-01       108.0516  149.9333
# 10 2023-09-01       107.5328   151.194
# 11 2023-10-01       107.3307  151.8005
# 12 2023-11-01        106.659  150.2488
# 13 2023-12-01       105.9498   149.036
# 14 2024-01-01       106.1015  161.2011
# 15 2024-02-01       105.7117  162.6236
# 16 2024-03-01       105.1746  161.8581
# 17 2024-04-01       105.6052  161.4541
# 18 2024-05-01       106.7913  159.6954
# 19 2024-06-01         107.25  159.5037
# 20 2024-07-01       108.2627   160.057
# 21 2024-08-01       107.8013  158.2215
# 22 2024-09-01       107.7157  157.1795
# 23 2024-10-01       106.8659   156.313
# 24 2024-11-01       105.7329  156.9732
# ...

# %%
df_clean['Nahrungsmittel'] = pd.to_numeric(df_clean['Nahrungsmittel'], errors='coerce')
df_clean
# Out:
# C:\Users\ursul\AppData\Local\Temp\ipykernel_17692\2790291847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Nahrungsmittel'] = pd.to_numeric(df_clean['Nahrungsmittel'], errors='coerce')
#          Date  Nahrungsmittel   Energie
# 2  2023-01-01        103.8223  154.1562
# 3  2023-02-01        104.9831  152.7693
# 4  2023-03-01        105.7529  151.8754
# 5  2023-04-01        104.7388  149.8897
# 6  2023-05-01        106.4792  147.2592
# 7  2023-06-01        107.6272   147.371
# 8  2023-07-01        108.1987  147.8984
# 9  2023-08-01        108.0516  149.9333
# 10 2023-09-01        107.5328   151.194
# 11 2023-10-01        107.3307  151.8005
# 12 2023-11-01        106.6590  150.2488
# ...

# %%
df_clean['Energie'] = pd.to_numeric(df_clean['Energie'], errors='coerce')
df_clean
# Out:
# C:\Users\ursul\AppData\Local\Temp\ipykernel_17692\2849469898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Energie'] = pd.to_numeric(df_clean['Energie'], errors='coerce')
#          Date  Nahrungsmittel   Energie
# 2  2023-01-01        103.8223  154.1562
# 3  2023-02-01        104.9831  152.7693
# 4  2023-03-01        105.7529  151.8754
# 5  2023-04-01        104.7388  149.8897
# 6  2023-05-01        106.4792  147.2592
# 7  2023-06-01        107.6272  147.3710
# 8  2023-07-01        108.1987  147.8984
# 9  2023-08-01        108.0516  149.9333
# 10 2023-09-01        107.5328  151.1940
# 11 2023-10-01        107.3307  151.8005
# 12 2023-11-01        106.6590  150.2488
# 13 2023-12-01        105.9498  149.0360
# ...

# %%
df_clean['Energie'] = df_clean['Energie'].round(2)
# Out:
# C:\Users\ursul\AppData\Local\Temp\ipykernel_17692\4200745349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Energie'] = df_clean['Energie'].round(2)

# %%
df_clean
# Out:
#          Date  Nahrungsmittel  Energie
# 2  2023-01-01        103.8223   154.16
# 3  2023-02-01        104.9831   152.77
# 4  2023-03-01        105.7529   151.88
# 5  2023-04-01        104.7388   149.89
# 6  2023-05-01        106.4792   147.26
# 7  2023-06-01        107.6272   147.37
# 8  2023-07-01        108.1987   147.90
# 9  2023-08-01        108.0516   149.93
# 10 2023-09-01        107.5328   151.19
# 11 2023-10-01        107.3307   151.80
# 12 2023-11-01        106.6590   150.25
# 13 2023-12-01        105.9498   149.04
# 14 2024-01-01        106.1015   161.20
# 15 2024-02-01        105.7117   162.62
# 16 2024-03-01        105.1746   161.86
# 17 2024-04-01        105.6052   161.45
# 18 2024-05-01        106.7913   159.70
# 19 2024-06-01        107.2500   159.50
# 20 2024-07-01        108.2627   160.06
# 21 2024-08-01        107.8013   158.22
# 22 2024-09-01        107.7157   157.18
# 23 2024-10-01        106.8659   156.31
# 24 2024-11-01        105.7329   156.97
# ...

# %%
df_clean['Nahrungsmittel'] = df_clean['Nahrungsmittel'].round(2)
# Out:
# C:\Users\ursul\AppData\Local\Temp\ipykernel_17692\1729363237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Nahrungsmittel'] = df_clean['Nahrungsmittel'].round(2)

# %%
df_clean
# Out:
#          Date  Nahrungsmittel  Energie
# 2  2023-01-01          103.82   154.16
# 3  2023-02-01          104.98   152.77
# 4  2023-03-01          105.75   151.88
# 5  2023-04-01          104.74   149.89
# 6  2023-05-01          106.48   147.26
# 7  2023-06-01          107.63   147.37
# 8  2023-07-01          108.20   147.90
# 9  2023-08-01          108.05   149.93
# 10 2023-09-01          107.53   151.19
# 11 2023-10-01          107.33   151.80
# 12 2023-11-01          106.66   150.25
# 13 2023-12-01          105.95   149.04
# 14 2024-01-01          106.10   161.20
# 15 2024-02-01          105.71   162.62
# 16 2024-03-01          105.17   161.86
# 17 2024-04-01          105.61   161.45
# 18 2024-05-01          106.79   159.70
# 19 2024-06-01          107.25   159.50
# 20 2024-07-01          108.26   160.06
# 21 2024-08-01          107.80   158.22
# 22 2024-09-01          107.72   157.18
# 23 2024-10-01          106.87   156.31
# 24 2024-11-01          105.73   156.97
# ...

# %%
df_clean.plot(x='Date', y=['Nahrungsmittel', 'Energie'], figsize=(12, 6), title='Verlauf von Nahrungsmittel und Energie')
# Out:
# <Axes: title={'center': 'Verlauf von Nahrungsmittel und Energie'}, xlabel='Date'>

# %%
#API key is: FXVYPBXKR5NBL662

import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=FXVYPBXKR5NBL662'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2025-07-08', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-07-08': {'1. open': '293.1000', '2. high': '295.6100', '3. low': '289.4900', '4. close': '290.4200', '5. volume': '2925329'}, '2025-07-07': {'1. open': '292.5000', '2. high': '295.2199', '3. low': '290.3607', '4. close': '292.4700', '5. volume': '4488064'}, '2025-07-03': {'1. open': '287.9400', '2. high': '292.3200', '3. low': '287.9000', '4. close': '291.9700', '5. volume': '1853289'}, '2025-07-02': {'1. open': '290.0000', '2. high': '290.1900', '3. low': '286.9000', '4. close': '287.6500', '5. volume': '3257515'}, '2025-07-01': {'1. open': '294.5500', '2. high': '295.1081', '3. low': '290.0800', '4. close': '291.2000', '5. volume': '3272797'}, '2025-06-30': {'1. open': '290.9300', '2. high': '294.8100', '3. low': '290.0000', '4. close': '294.7800', '5. vo
# ...

# %%
df_C = pd.read_excel('Kaffee_preise.xlsx')
df_C.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Jan 2003   Feb 2003   Mar 2003   Apr 2003  \
# 0         NaN      Index  65.153378  70.229514  65.782768  61.887199
#
#     May 2003   Jun 2003   Jul 2003   Aug 2003  ...   Aug 2024    Sep 2024  \
# 0  63.065977  64.384352  63.303971  64.423874  ...  164.17477  161.455216
#
#      Oct 2024    Nov 2024    Dec 2024    Jan 2025    Feb 2025    Mar 2025  \
# 0  166.512349  166.207253  166.634365  172.779129  172.016298  167.408117
#
#      Apr 2025    May 2025
# 0  162.563712  160.924616
#
# [1 rows x 271 columns]

# %%
# Spalte 'Unnamed: 0' und Ähnliche bereinigen (optional, falls Indexspalten)
df_C = df_C.loc[:, ~df_C.columns.str.contains('^Unnamed')]

# Liste der Spalten ab Juni 2023 extrahieren
start_col = 'Jan 2023'
cols_to_keep = df_C.columns[df_C.columns.get_loc(start_col):]

# Neuen DataFrame mit nur diesen Spalten
df_C_filtered = df_C[cols_to_keep]

# Optional: Ausgabe zur Kontrolle
print(df_C_filtered.head())
# Out:
#      Jan 2023    Feb 2023    Mar 2023    Apr 2023    May 2023    Jun 2023  \
# 0  182.636277  174.561286  168.300259  170.764655  157.134012  154.069169
#
#      Jul 2023    Aug 2023    Sep 2023    Oct 2023  ...   Aug 2024    Sep 2024  \
# 0  157.908976  161.271623  168.607096  167.909338  ...  164.17477  161.455216
#
#      Oct 2024    Nov 2024    Dec 2024    Jan 2025    Feb 2025    Mar 2025  \
# 0  166.512349  166.207253  166.634365  172.779129  172.016298  167.408117
#
#      Apr 2025    May 2025
# 0  162.563712  160.924616
#
# [1 rows x 29 columns]

# %%
df_C_filtered.columns = pd.to_datetime(df_C_filtered.columns, format='%b %Y')

# Optional: Ausgabe zur Kontrolle
print(df_C_filtered.columns)
print(type(df_C_filtered.columns[0]))
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01',
#                '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01',
#                '2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#                '2025-05-01'],
#               dtype='datetime64[ns]', freq=None)
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# Transponiere, damit jede Zeile ein Datum ist
df_C_transposed = df_C_filtered.transpose().reset_index()

# Umbenennen für Klarheit
df_C_transposed.columns = ['Date'] + [f'Kaffee_{i}' for i in range(1, len(df_C_transposed.columns))]

# Stelle sicher, dass Date wirklich datetime ist
df_C_transposed['Date'] = pd.to_datetime(df_C_transposed['Date'])

# %%
# Nach Datum mergen
df_merged = pd.merge(df_clean, df_C_transposed, on='Date', how='outer').sort_values('Date')

# %%
df_merged.plot(
    x='Date',
    y=['Nahrungsmittel', 'Energie'] + list(df_C_transposed.columns[1:]),
    figsize=(12, 6),
    title='Verlauf von Nahrungsmittel, Energie und Kaffee'
)
# Out:
# <Axes: title={'center': 'Verlauf von Nahrungsmittel, Energie und Kaffee'}, xlabel='Date'>

# %%
df_export = df_merged[['Date', 'Nahrungsmittel', 'Energie'] + list(df_C_transposed.columns[1:])]
df_export['Date'] = df_export['Date'].dt.strftime('%Y-%m-%d')  # Optional: Datum als Text
df_export.to_csv('datawrapper_input.csv', index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Beispiel: Nur die ersten 15 Zeilen anzeigen (bei Bedarf anpassen)
df_table = df_export.head(15)

# Figure erstellen
fig, ax = plt.subplots(figsize=(12, 0.5 + 0.4 * len(df_table)))  # Höhe dynamisch
ax.axis('off')  # keine Achsen anzeigen

# Tabelle einfügen
table = plt.table(
    cellText=df_table.values,
    colLabels=df_table.columns,
    cellLoc='center',
    loc='center'
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)  # Spaltenbreite, Zeilenhöhe anpassen

# SVG speichern
plt.savefig('energie_tabelle.svg', format='svg', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

# Plot erstellen und Axes-Objekt zurückholen
ax = df_merged.plot(
    x='Date',
    y=['Nahrungsmittel', 'Energie'] + list(df_C_transposed.columns[1:]),
    figsize=(12, 6),
    title='Verlauf von Nahrungsmittel, Energie und Kaffee'
)

# Layout justieren (wichtig für SVG)
plt.tight_layout()

# 🎯 Als SVG speichern
plt.savefig('nahrungsmittel_energie_kaffee.svg', format='svg')
